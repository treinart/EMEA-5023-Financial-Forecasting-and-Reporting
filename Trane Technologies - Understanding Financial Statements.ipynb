# %% [markdown]
# <div style="background-color:#F8F8F8;padding:25px;border-radius:15px;border-top:1px solid #CFB87C;border-bottom:1px solid #CFB87C;border-left:8px solid #CFB87C;border-right:8px solid #565A5C;font-family:Helvetica Neue,Arial,sans-serif;text-align:center;">
# <h1 style="color:#565A5C;font-size:42px;font-weight:bold;margin:0 0 8px 0;">Trane Technologies Financial Statement Analysis</h1>
# <h2 style="color:#CFB87C;font-size:31px;font-weight:bold;margin:0 0 10px 0;">Understanding Financial Statements</h2>
# <p style="color:#000000;font-size:17px;margin:0 0 14px 0;">Financial Forecasting and Reporting, Module 2</p>
# <span style="display:inline-block;background:#000000;color:#CFB87C;padding:8px 14px;border-radius:999px;margin:4px;font-weight:bold;">NYSE: TT</span>
# <span style="display:inline-block;background:#000000;color:#CFB87C;padding:8px 14px;border-radius:999px;margin:4px;font-weight:bold;">Thermo King vendor relevance</span>
# <span style="display:inline-block;background:#000000;color:#CFB87C;padding:8px 14px;border-radius:999px;margin:4px;font-weight:bold;">2025 Annual Report</span>
# <span style="display:inline-block;background:#000000;color:#CFB87C;padding:8px 14px;border-radius:999px;margin:4px;font-weight:bold;">Dollars in millions</span>
# </div>

# %% [markdown]
# <div style="background-color:#000000;color:#F8F8F8;padding:25px;border-radius:10px;border-left:8px solid #CFB87C;border-right:8px solid #A2A4A3;font-family:Helvetica Neue,Arial,sans-serif;">
# <h2 style="color:#CFB87C;margin:0 0 14px 0;">Bottom Line</h2>
# <p style="font-size:16px;line-height:1.6;margin:0 0 12px 0;">Trane Technologies looks financially healthy based on the 2025 annual financial statements. The company grew revenue, expanded margins, generated strong earnings, and produced substantial operating cash flow.</p><div style="display:inline-block;vertical-align:top;width:205px;min-height:78px;background-color:#111111;border:1px solid #565A5C;border-left:6px solid #CFB87C;border-radius:8px;padding:12px;margin:6px;"><div style="color:#A2A4A3;font-size:12px;text-transform:uppercase;letter-spacing:.06em;">2025 Net Revenues</div><div style="color:#F8F8F8;font-size:23px;font-weight:bold;margin-top:7px;">&#36;21,321.9M</div></div><div style="display:inline-block;vertical-align:top;width:205px;min-height:78px;background-color:#111111;border:1px solid #565A5C;border-left:6px solid #CFB87C;border-radius:8px;padding:12px;margin:6px;"><div style="color:#A2A4A3;font-size:12px;text-transform:uppercase;letter-spacing:.06em;">Operating Income</div><div style="color:#F8F8F8;font-size:23px;font-weight:bold;margin-top:7px;">&#36;3,967.4M</div></div><div style="display:inline-block;vertical-align:top;width:205px;min-height:78px;background-color:#111111;border:1px solid #565A5C;border-left:6px solid #CFB87C;border-radius:8px;padding:12px;margin:6px;"><div style="color:#A2A4A3;font-size:12px;text-transform:uppercase;letter-spacing:.06em;">Net Earnings</div><div style="color:#F8F8F8;font-size:23px;font-weight:bold;margin-top:7px;">&#36;2,918.6M</div></div><div style="display:inline-block;vertical-align:top;width:205px;min-height:78px;background-color:#111111;border:1px solid #565A5C;border-left:6px solid #CFB87C;border-radius:8px;padding:12px;margin:6px;"><div style="color:#A2A4A3;font-size:12px;text-transform:uppercase;letter-spacing:.06em;">Operating Cash Flow</div><div style="color:#F8F8F8;font-size:23px;font-weight:bold;margin-top:7px;">&#36;3,194.5M</div></div><p style="font-size:16px;line-height:1.6;margin:0 0 12px 0;">I chose Trane because Thermo King is part of Trane Technologies, and Thermo King is my primary vendor.</p>
# <hr style="border:none;border-top:8px solid #CFB87C;margin:18px 0 0 0;">
# </div>

# %% [markdown]
# <div style="background-color:#000000;color:#F8F8F8;padding:25px;border-radius:10px;border-left:8px solid #CFB87C;border-right:8px solid #A2A4A3;font-family:Helvetica Neue,Arial,sans-serif;">
# <h2 style="color:#A2A4A3;margin:0 0 12px 0;">Notebook Flow</h2>
# <p style="font-size:16px;line-height:1.6;margin:0;">Company overview, products and services, financial statement analysis, ratio math, required annual report screenshots, then a short annual trend review.</p>
# <hr style="border:none;border-top:8px solid #CFB87C;margin:18px 0 0 0;">
# </div>

# %% [markdown]
# <div style="background-color:#000000;color:#F8F8F8;padding:25px;border-radius:10px;border-left:8px solid #CFB87C;border-right:8px solid #A2A4A3;font-family:Helvetica Neue,Arial,sans-serif;">
# <h2 style="color:#A2A4A3;margin:0 0 12px 0;">Part 1: Company Overview</h2>
# <p style="font-size:16px;line-height:1.6;margin:0;">Trane Technologies is a global climate company focused on HVAC, refrigeration, transport temperature control, controls, and related services.</p>
# <hr style="border:none;border-top:8px solid #CFB87C;margin:18px 0 0 0;">
# </div>

# %% [markdown]
# <div style="background-color:#000000;color:#F8F8F8;padding:25px;border-radius:10px;border-left:8px solid #CFB87C;border-right:8px solid #A2A4A3;font-family:Helvetica Neue,Arial,sans-serif;">
# <h2 style="color:#CFB87C;margin:0 0 14px 0;">Why this company matters</h2>
# <p style="font-size:16px;line-height:1.6;margin:0 0 12px 0;">Trane Technologies plc is listed on the New York Stock Exchange under ticker TT. Its major brands include Trane and Thermo King. The company reports through Americas, EMEA, and Asia Pacific.</p><p style="font-size:16px;line-height:1.6;margin:0 0 12px 0;">I selected Trane Technologies because Thermo King is part of Trane Technologies. Thermo King is my primary vendor, so we track Trane Technologies closely because the health of our primary vendor is important to my financial well being and employment.</p>
# <hr style="border:none;border-top:8px solid #CFB87C;margin:18px 0 0 0;">
# </div>

# %% [markdown]
# <div style="background-color:#000000;color:#F8F8F8;padding:25px;border-radius:10px;border-left:8px solid #CFB87C;border-right:8px solid #A2A4A3;font-family:Helvetica Neue,Arial,sans-serif;">
# <h2 style="color:#A2A4A3;margin:0 0 12px 0;">Part 2: Products and Services</h2>
# <p style="font-size:16px;line-height:1.6;margin:0;">Trane is not just an equipment company. It sells equipment, service, controls, and recurring support that keep buildings and refrigerated transport systems running.</p>
# <hr style="border:none;border-top:8px solid #CFB87C;margin:18px 0 0 0;">
# </div>

# %% [markdown]
# <div style="background-color:#000000;color:#F8F8F8;padding:25px;border-radius:10px;border-left:8px solid #CFB87C;border-right:8px solid #A2A4A3;font-family:Helvetica Neue,Arial,sans-serif;">
# <h2 style="color:#CFB87C;margin:0 0 14px 0;">Business lines in plain English</h2>
# <ul style="font-size:16px;line-height:1.55;margin:0 0 8px 22px;padding:0;"><li style="margin:5px 0;"><strong>Trane:</strong> commercial and residential HVAC equipment, building systems, controls, and services.</li><li style="margin:5px 0;"><strong>Thermo King:</strong> transport refrigeration and temperature-control systems for trailers, trucks, rail, marine, and cold chain applications.</li><li style="margin:5px 0;"><strong>Services:</strong> maintenance, repair, lifecycle support, controls, and building efficiency work.</li><li style="margin:5px 0;"><strong>Strategic theme:</strong> sustainability, energy efficiency, electrification, and climate-focused infrastructure.</li></ul>
# <hr style="border:none;border-top:8px solid #CFB87C;margin:18px 0 0 0;">
# </div>

# %% [markdown]
# <div style="background-color:#000000;color:#F8F8F8;padding:25px;border-radius:10px;border-left:8px solid #A2A4A3;border-right:8px solid #A2A4A3;font-family:Helvetica Neue,Arial,sans-serif;">
# <h2 style="color:#CFB87C;margin:0 0 14px 0;">Company-provided performance snapshot</h2>
# <div style="background-color:#F8F8F8;padding:10px;border-radius:8px;text-align:center;"><img src="images/q4_2025_slide_05.png" alt="Company-provided performance snapshot" style="width:100%;max-width:850px;height:auto;"></div><p style="font-size:14px;color:#A2A4A3;line-height:1.5;margin:12px 0 0 0;">Source: Trane Technologies Q4 2025 Earnings Presentation, slide 5. This is company-provided presentation material and includes non-GAAP measures noted on the slide.</p>
# <hr style="border:none;border-top:8px solid #CFB87C;margin:18px 0 0 0;">
# </div>

# %% [markdown]
# <div style="background-color:#000000;color:#F8F8F8;padding:25px;border-radius:10px;border-left:8px solid #CFB87C;border-right:8px solid #A2A4A3;font-family:Helvetica Neue,Arial,sans-serif;">
# <h2 style="color:#A2A4A3;margin:0 0 12px 0;">Part 3: Financial Analysis</h2>
# <p style="font-size:16px;line-height:1.6;margin:0;">This section ties the three financial statements to the ratios from Module 2.</p>
# <hr style="border:none;border-top:8px solid #CFB87C;margin:18px 0 0 0;">
# </div>

# %% [markdown]
# <div style="background-color:#000000;color:#F8F8F8;padding:25px;border-radius:10px;border-left:8px solid #CFB87C;border-right:8px solid #A2A4A3;font-family:Helvetica Neue,Arial,sans-serif;">
# <h2 style="color:#CFB87C;margin:0 0 14px 0;">Income statement readout</h2>
# <p style="font-size:16px;line-height:1.6;margin:0 0 12px 0;">Revenue grew to &#36;21,321.9 million in 2025. Operating income was &#36;3,967.4 million, and net earnings attributable to Trane Technologies were &#36;2,918.6 million.</p><div style="display:inline-block;vertical-align:top;width:205px;min-height:78px;background-color:#111111;border:1px solid #565A5C;border-left:6px solid #CFB87C;border-radius:8px;padding:12px;margin:6px;"><div style="color:#A2A4A3;font-size:12px;text-transform:uppercase;letter-spacing:.06em;">Gross Margin</div><div style="color:#F8F8F8;font-size:23px;font-weight:bold;margin-top:7px;">36.2%</div></div><div style="display:inline-block;vertical-align:top;width:205px;min-height:78px;background-color:#111111;border:1px solid #565A5C;border-left:6px solid #CFB87C;border-radius:8px;padding:12px;margin:6px;"><div style="color:#A2A4A3;font-size:12px;text-transform:uppercase;letter-spacing:.06em;">Operating Margin</div><div style="color:#F8F8F8;font-size:23px;font-weight:bold;margin-top:7px;">18.6%</div></div><div style="display:inline-block;vertical-align:top;width:205px;min-height:78px;background-color:#111111;border:1px solid #565A5C;border-left:6px solid #CFB87C;border-radius:8px;padding:12px;margin:6px;"><div style="color:#A2A4A3;font-size:12px;text-transform:uppercase;letter-spacing:.06em;">Net Margin</div><div style="color:#F8F8F8;font-size:23px;font-weight:bold;margin-top:7px;">13.7%</div></div><div style="display:inline-block;vertical-align:top;width:205px;min-height:78px;background-color:#111111;border:1px solid #565A5C;border-left:6px solid #CFB87C;border-radius:8px;padding:12px;margin:6px;"><div style="color:#A2A4A3;font-size:12px;text-transform:uppercase;letter-spacing:.06em;">Diluted EPS</div><div style="color:#F8F8F8;font-size:23px;font-weight:bold;margin-top:7px;">&#36;12.98</div></div><p style="font-size:16px;line-height:1.6;margin:0 0 12px 0;">The useful point is that 2025 was not only larger than prior years. The margin profile was stronger too.</p>
# <hr style="border:none;border-top:8px solid #CFB87C;margin:18px 0 0 0;">
# </div>

# %% [markdown]
# <div style="background-color:#000000;color:#F8F8F8;padding:25px;border-radius:10px;border-left:8px solid #CFB87C;border-right:8px solid #A2A4A3;font-family:Helvetica Neue,Arial,sans-serif;">
# <h2 style="color:#CFB87C;margin:0 0 14px 0;">Balance sheet readout</h2>
# <p style="font-size:16px;line-height:1.6;margin:0 0 12px 0;">Total assets were &#36;21,420.7 million. Total liabilities were &#36;12,819.8 million. Shareholders' equity was &#36;8,579.2 million.</p><div style="display:inline-block;vertical-align:top;width:205px;min-height:78px;background-color:#111111;border:1px solid #565A5C;border-left:6px solid #CFB87C;border-radius:8px;padding:12px;margin:6px;"><div style="color:#A2A4A3;font-size:12px;text-transform:uppercase;letter-spacing:.06em;">Current Ratio</div><div style="color:#F8F8F8;font-size:23px;font-weight:bold;margin-top:7px;">1.25</div></div><div style="display:inline-block;vertical-align:top;width:205px;min-height:78px;background-color:#111111;border:1px solid #565A5C;border-left:6px solid #CFB87C;border-radius:8px;padding:12px;margin:6px;"><div style="color:#A2A4A3;font-size:12px;text-transform:uppercase;letter-spacing:.06em;">Quick Ratio</div><div style="color:#F8F8F8;font-size:23px;font-weight:bold;margin-top:7px;">0.92</div></div><div style="display:inline-block;vertical-align:top;width:205px;min-height:78px;background-color:#111111;border:1px solid #565A5C;border-left:6px solid #CFB87C;border-radius:8px;padding:12px;margin:6px;"><div style="color:#A2A4A3;font-size:12px;text-transform:uppercase;letter-spacing:.06em;">Debt Ratio</div><div style="color:#F8F8F8;font-size:23px;font-weight:bold;margin-top:7px;">59.8%</div></div><div style="display:inline-block;vertical-align:top;width:205px;min-height:78px;background-color:#111111;border:1px solid #565A5C;border-left:6px solid #CFB87C;border-radius:8px;padding:12px;margin:6px;"><div style="color:#A2A4A3;font-size:12px;text-transform:uppercase;letter-spacing:.06em;">Debt-to-Equity</div><div style="color:#F8F8F8;font-size:23px;font-weight:bold;margin-top:7px;">1.49</div></div><p style="font-size:16px;line-height:1.6;margin:0 0 12px 0;">The company uses leverage, but the liquidity and coverage ratios do not point to near-term stress.</p>
# <hr style="border:none;border-top:8px solid #CFB87C;margin:18px 0 0 0;">
# </div>

# %% [markdown]
# <div style="background-color:#000000;color:#F8F8F8;padding:25px;border-radius:10px;border-left:8px solid #CFB87C;border-right:8px solid #A2A4A3;font-family:Helvetica Neue,Arial,sans-serif;">
# <h2 style="color:#CFB87C;margin:0 0 14px 0;">Cash flow readout</h2>
# <p style="font-size:16px;line-height:1.6;margin:0 0 12px 0;">Operating cash flow was &#36;3,194.5 million in 2025. Investing cash flow was negative, which is normal for a company investing in assets and growth. Financing cash flow was also negative, which usually reflects dividends, share repurchases, debt activity, or other capital returns.</p><div style="display:inline-block;vertical-align:top;width:205px;min-height:78px;background-color:#111111;border:1px solid #565A5C;border-left:6px solid #CFB87C;border-radius:8px;padding:12px;margin:6px;"><div style="color:#A2A4A3;font-size:12px;text-transform:uppercase;letter-spacing:.06em;">Operating Cash Flow</div><div style="color:#F8F8F8;font-size:23px;font-weight:bold;margin-top:7px;">&#36;3,194.5M</div></div><div style="display:inline-block;vertical-align:top;width:205px;min-height:78px;background-color:#111111;border:1px solid #565A5C;border-left:6px solid #CFB87C;border-radius:8px;padding:12px;margin:6px;"><div style="color:#A2A4A3;font-size:12px;text-transform:uppercase;letter-spacing:.06em;">Investing Cash Flow</div><div style="color:#F8F8F8;font-size:23px;font-weight:bold;margin-top:7px;">-&#36;640.0M</div></div><div style="display:inline-block;vertical-align:top;width:205px;min-height:78px;background-color:#111111;border:1px solid #565A5C;border-left:6px solid #CFB87C;border-radius:8px;padding:12px;margin:6px;"><div style="color:#A2A4A3;font-size:12px;text-transform:uppercase;letter-spacing:.06em;">Financing Cash Flow</div><div style="color:#F8F8F8;font-size:23px;font-weight:bold;margin-top:7px;">-&#36;2,495.8M</div></div><div style="display:inline-block;vertical-align:top;width:205px;min-height:78px;background-color:#111111;border:1px solid #565A5C;border-left:6px solid #CFB87C;border-radius:8px;padding:12px;margin:6px;"><div style="color:#A2A4A3;font-size:12px;text-transform:uppercase;letter-spacing:.06em;">CapEx</div><div style="color:#F8F8F8;font-size:23px;font-weight:bold;margin-top:7px;">-&#36;383.0M</div></div><p style="font-size:16px;line-height:1.6;margin:0 0 12px 0;">The cash flow statement supports the same story as the income statement: Trane is generating real cash, not just accounting earnings.</p>
# <hr style="border:none;border-top:8px solid #CFB87C;margin:18px 0 0 0;">
# </div>

# %% [markdown]
# <div style="background-color:#000000;color:#F8F8F8;padding:25px;border-radius:10px;border-left:8px solid #CFB87C;border-right:8px solid #A2A4A3;font-family:Helvetica Neue,Arial,sans-serif;">
# <h2 style="color:#A2A4A3;margin:0 0 12px 0;">2025 Ratio Math</h2>
# <p style="font-size:16px;line-height:1.6;margin:0;">Each ratio below uses the 2025 annual report values. The equations are built as styled HTML so VS Code does not show raw LaTeX or raw tags.</p>
# <hr style="border:none;border-top:8px solid #CFB87C;margin:18px 0 0 0;">
# </div>

# %% [markdown]
# <div style="background-color:#000000;color:#F8F8F8;padding:25px;border-radius:10px;border-left:8px solid #CFB87C;border-right:8px solid #A2A4A3;font-family:Helvetica Neue,Arial,sans-serif;">
# <h2 style="color:#CFB87C;margin:0 0 14px 0;">Current Ratio</h2>
# <div style="font-size:34px;font-weight:bold;color:#F8F8F8;margin:0 0 16px 0;">1.25</div><div style="background-color:#111111;color:#F8F8F8;padding:18px;border-radius:8px;border:1px solid #565A5C;text-align:center;font-size:19px;line-height:1.45;overflow-x:auto;"><div style="margin:7px 0;">Current Ratio = <span style="display:inline-block;text-align:center;vertical-align:middle;line-height:1.15;margin:0 6px;"><span style="display:block;border-bottom:1px solid #F8F8F8;padding:0 10px;">Current Assets</span><span style="display:block;padding:2px 10px 0 10px;">Current Liabilities</span></span></div><div style="margin:7px 0;">= <span style="display:inline-block;text-align:center;vertical-align:middle;line-height:1.15;margin:0 6px;"><span style="display:block;border-bottom:1px solid #F8F8F8;padding:0 10px;">7,863.0</span><span style="display:block;padding:2px 10px 0 10px;">6,286.7</span></span></div><div style="margin:7px 0;">= 1.25</div></div><p style="font-size:16px;line-height:1.6;margin:14px 0 0 0;"><strong style="color:#CFB87C;">Readout:</strong> Trane has 1.25 dollars of current assets for every 1.00 dollar of current liabilities.</p>
# <hr style="border:none;border-top:8px solid #CFB87C;margin:18px 0 0 0;">
# </div>

# %% [markdown]
# <div style="background-color:#000000;color:#F8F8F8;padding:25px;border-radius:10px;border-left:8px solid #CFB87C;border-right:8px solid #A2A4A3;font-family:Helvetica Neue,Arial,sans-serif;">
# <h2 style="color:#CFB87C;margin:0 0 14px 0;">Quick Ratio</h2>
# <div style="font-size:34px;font-weight:bold;color:#F8F8F8;margin:0 0 16px 0;">0.92</div><div style="background-color:#111111;color:#F8F8F8;padding:18px;border-radius:8px;border:1px solid #565A5C;text-align:center;font-size:19px;line-height:1.45;overflow-x:auto;"><div style="margin:7px 0;">Quick Ratio = <span style="display:inline-block;text-align:center;vertical-align:middle;line-height:1.15;margin:0 6px;"><span style="display:block;border-bottom:1px solid #F8F8F8;padding:0 10px;">Current Assets - Inventory</span><span style="display:block;padding:2px 10px 0 10px;">Current Liabilities</span></span></div><div style="margin:7px 0;">= <span style="display:inline-block;text-align:center;vertical-align:middle;line-height:1.15;margin:0 6px;"><span style="display:block;border-bottom:1px solid #F8F8F8;padding:0 10px;">7,863.0 - 2,103.6</span><span style="display:block;padding:2px 10px 0 10px;">6,286.7</span></span></div><div style="margin:7px 0;">= 0.92</div></div><p style="font-size:16px;line-height:1.6;margin:14px 0 0 0;"><strong style="color:#CFB87C;">Readout:</strong> After removing inventory, Trane has 0.92 dollars of quick assets for every 1.00 dollar of current liabilities.</p>
# <hr style="border:none;border-top:8px solid #CFB87C;margin:18px 0 0 0;">
# </div>

# %% [markdown]
# <div style="background-color:#000000;color:#F8F8F8;padding:25px;border-radius:10px;border-left:8px solid #CFB87C;border-right:8px solid #A2A4A3;font-family:Helvetica Neue,Arial,sans-serif;">
# <h2 style="color:#CFB87C;margin:0 0 14px 0;">Inventory Turnover</h2>
# <div style="font-size:34px;font-weight:bold;color:#F8F8F8;margin:0 0 16px 0;">6.47</div><div style="background-color:#111111;color:#F8F8F8;padding:18px;border-radius:8px;border:1px solid #565A5C;text-align:center;font-size:19px;line-height:1.45;overflow-x:auto;"><div style="margin:7px 0;">Inventory Turnover = <span style="display:inline-block;text-align:center;vertical-align:middle;line-height:1.15;margin:0 6px;"><span style="display:block;border-bottom:1px solid #F8F8F8;padding:0 10px;">Cost of Goods Sold</span><span style="display:block;padding:2px 10px 0 10px;">Inventory</span></span></div><div style="margin:7px 0;">= <span style="display:inline-block;text-align:center;vertical-align:middle;line-height:1.15;margin:0 6px;"><span style="display:block;border-bottom:1px solid #F8F8F8;padding:0 10px;">13,611.7</span><span style="display:block;padding:2px 10px 0 10px;">2,103.6</span></span></div><div style="margin:7px 0;">= 6.47</div></div><p style="font-size:16px;line-height:1.6;margin:14px 0 0 0;"><strong style="color:#CFB87C;">Readout:</strong> Trane turns inventory into cost of sales about 6.47 times per year using this simple course formula.</p><p style="font-size:14px;color:#A2A4A3;line-height:1.5;margin:10px 0 0 0;"><strong style="color:#CFB87C;">Note:</strong> This uses ending inventory because that is the simple version used for the ratio walkthrough.</p>
# <hr style="border:none;border-top:8px solid #CFB87C;margin:18px 0 0 0;">
# </div>

# %% [markdown]
# <div style="background-color:#000000;color:#F8F8F8;padding:25px;border-radius:10px;border-left:8px solid #CFB87C;border-right:8px solid #A2A4A3;font-family:Helvetica Neue,Arial,sans-serif;">
# <h2 style="color:#CFB87C;margin:0 0 14px 0;">Days Sales Outstanding</h2>
# <div style="font-size:34px;font-weight:bold;color:#F8F8F8;margin:0 0 16px 0;">55.4 days</div><div style="background-color:#111111;color:#F8F8F8;padding:18px;border-radius:8px;border:1px solid #565A5C;text-align:center;font-size:19px;line-height:1.45;overflow-x:auto;"><div style="margin:7px 0;">DSO = <span style="display:inline-block;text-align:center;vertical-align:middle;line-height:1.15;margin:0 6px;"><span style="display:block;border-bottom:1px solid #F8F8F8;padding:0 10px;">Accounts Receivable</span><span style="display:block;padding:2px 10px 0 10px;">Net Revenues / 365</span></span></div><div style="margin:7px 0;">= <span style="display:inline-block;text-align:center;vertical-align:middle;line-height:1.15;margin:0 6px;"><span style="display:block;border-bottom:1px solid #F8F8F8;padding:0 10px;">3,235.3</span><span style="display:block;padding:2px 10px 0 10px;">21,321.9 / 365</span></span></div><div style="margin:7px 0;">= 55.4 days</div></div><p style="font-size:16px;line-height:1.6;margin:14px 0 0 0;"><strong style="color:#CFB87C;">Readout:</strong> Receivables represent about 55.4 days of sales.</p>
# <hr style="border:none;border-top:8px solid #CFB87C;margin:18px 0 0 0;">
# </div>

# %% [markdown]
# <div style="background-color:#000000;color:#F8F8F8;padding:25px;border-radius:10px;border-left:8px solid #CFB87C;border-right:8px solid #A2A4A3;font-family:Helvetica Neue,Arial,sans-serif;">
# <h2 style="color:#CFB87C;margin:0 0 14px 0;">Gross Margin</h2>
# <div style="font-size:34px;font-weight:bold;color:#F8F8F8;margin:0 0 16px 0;">36.2%</div><div style="background-color:#111111;color:#F8F8F8;padding:18px;border-radius:8px;border:1px solid #565A5C;text-align:center;font-size:19px;line-height:1.45;overflow-x:auto;"><div style="margin:7px 0;">Gross Margin = <span style="display:inline-block;text-align:center;vertical-align:middle;line-height:1.15;margin:0 6px;"><span style="display:block;border-bottom:1px solid #F8F8F8;padding:0 10px;">Gross Profit</span><span style="display:block;padding:2px 10px 0 10px;">Net Revenues</span></span></div><div style="margin:7px 0;">= <span style="display:inline-block;text-align:center;vertical-align:middle;line-height:1.15;margin:0 6px;"><span style="display:block;border-bottom:1px solid #F8F8F8;padding:0 10px;">7,710.2</span><span style="display:block;padding:2px 10px 0 10px;">21,321.9</span></span></div><div style="margin:7px 0;">= 36.2%</div></div><p style="font-size:16px;line-height:1.6;margin:14px 0 0 0;"><strong style="color:#CFB87C;">Readout:</strong> Trane kept 36.2% of revenue after product and service costs.</p>
# <hr style="border:none;border-top:8px solid #CFB87C;margin:18px 0 0 0;">
# </div>

# %% [markdown]
# <div style="background-color:#000000;color:#F8F8F8;padding:25px;border-radius:10px;border-left:8px solid #CFB87C;border-right:8px solid #A2A4A3;font-family:Helvetica Neue,Arial,sans-serif;">
# <h2 style="color:#CFB87C;margin:0 0 14px 0;">Operating Margin</h2>
# <div style="font-size:34px;font-weight:bold;color:#F8F8F8;margin:0 0 16px 0;">18.6%</div><div style="background-color:#111111;color:#F8F8F8;padding:18px;border-radius:8px;border:1px solid #565A5C;text-align:center;font-size:19px;line-height:1.45;overflow-x:auto;"><div style="margin:7px 0;">Operating Margin = <span style="display:inline-block;text-align:center;vertical-align:middle;line-height:1.15;margin:0 6px;"><span style="display:block;border-bottom:1px solid #F8F8F8;padding:0 10px;">Operating Income</span><span style="display:block;padding:2px 10px 0 10px;">Net Revenues</span></span></div><div style="margin:7px 0;">= <span style="display:inline-block;text-align:center;vertical-align:middle;line-height:1.15;margin:0 6px;"><span style="display:block;border-bottom:1px solid #F8F8F8;padding:0 10px;">3,967.4</span><span style="display:block;padding:2px 10px 0 10px;">21,321.9</span></span></div><div style="margin:7px 0;">= 18.6%</div></div><p style="font-size:16px;line-height:1.6;margin:14px 0 0 0;"><strong style="color:#CFB87C;">Readout:</strong> Trane converted 18.6% of revenue into operating income.</p>
# <hr style="border:none;border-top:8px solid #CFB87C;margin:18px 0 0 0;">
# </div>

# %% [markdown]
# <div style="background-color:#000000;color:#F8F8F8;padding:25px;border-radius:10px;border-left:8px solid #CFB87C;border-right:8px solid #A2A4A3;font-family:Helvetica Neue,Arial,sans-serif;">
# <h2 style="color:#CFB87C;margin:0 0 14px 0;">Net Margin</h2>
# <div style="font-size:34px;font-weight:bold;color:#F8F8F8;margin:0 0 16px 0;">13.7%</div><div style="background-color:#111111;color:#F8F8F8;padding:18px;border-radius:8px;border:1px solid #565A5C;text-align:center;font-size:19px;line-height:1.45;overflow-x:auto;"><div style="margin:7px 0;">Net Margin = <span style="display:inline-block;text-align:center;vertical-align:middle;line-height:1.15;margin:0 6px;"><span style="display:block;border-bottom:1px solid #F8F8F8;padding:0 10px;">Net Earnings Attributable to Trane</span><span style="display:block;padding:2px 10px 0 10px;">Net Revenues</span></span></div><div style="margin:7px 0;">= <span style="display:inline-block;text-align:center;vertical-align:middle;line-height:1.15;margin:0 6px;"><span style="display:block;border-bottom:1px solid #F8F8F8;padding:0 10px;">2,918.6</span><span style="display:block;padding:2px 10px 0 10px;">21,321.9</span></span></div><div style="margin:7px 0;">= 13.7%</div></div><p style="font-size:16px;line-height:1.6;margin:14px 0 0 0;"><strong style="color:#CFB87C;">Readout:</strong> Trane converted 13.7% of revenue into earnings attributable to shareholders.</p>
# <hr style="border:none;border-top:8px solid #CFB87C;margin:18px 0 0 0;">
# </div>

# %% [markdown]
# <div style="background-color:#000000;color:#F8F8F8;padding:25px;border-radius:10px;border-left:8px solid #CFB87C;border-right:8px solid #A2A4A3;font-family:Helvetica Neue,Arial,sans-serif;">
# <h2 style="color:#CFB87C;margin:0 0 14px 0;">Debt Ratio</h2>
# <div style="font-size:34px;font-weight:bold;color:#F8F8F8;margin:0 0 16px 0;">59.8%</div><div style="background-color:#111111;color:#F8F8F8;padding:18px;border-radius:8px;border:1px solid #565A5C;text-align:center;font-size:19px;line-height:1.45;overflow-x:auto;"><div style="margin:7px 0;">Debt Ratio = <span style="display:inline-block;text-align:center;vertical-align:middle;line-height:1.15;margin:0 6px;"><span style="display:block;border-bottom:1px solid #F8F8F8;padding:0 10px;">Total Liabilities</span><span style="display:block;padding:2px 10px 0 10px;">Total Assets</span></span></div><div style="margin:7px 0;">= <span style="display:inline-block;text-align:center;vertical-align:middle;line-height:1.15;margin:0 6px;"><span style="display:block;border-bottom:1px solid #F8F8F8;padding:0 10px;">12,819.8</span><span style="display:block;padding:2px 10px 0 10px;">21,420.7</span></span></div><div style="margin:7px 0;">= 59.8%</div></div><p style="font-size:16px;line-height:1.6;margin:14px 0 0 0;"><strong style="color:#CFB87C;">Readout:</strong> About 59.8% of assets are financed by liabilities under this broad ratio.</p><p style="font-size:14px;color:#A2A4A3;line-height:1.5;margin:10px 0 0 0;"><strong style="color:#CFB87C;">Note:</strong> This uses total liabilities as the course-style debt proxy.</p>
# <hr style="border:none;border-top:8px solid #CFB87C;margin:18px 0 0 0;">
# </div>

# %% [markdown]
# <div style="background-color:#000000;color:#F8F8F8;padding:25px;border-radius:10px;border-left:8px solid #CFB87C;border-right:8px solid #A2A4A3;font-family:Helvetica Neue,Arial,sans-serif;">
# <h2 style="color:#CFB87C;margin:0 0 14px 0;">Debt-to-Equity Ratio</h2>
# <div style="font-size:34px;font-weight:bold;color:#F8F8F8;margin:0 0 16px 0;">1.49</div><div style="background-color:#111111;color:#F8F8F8;padding:18px;border-radius:8px;border:1px solid #565A5C;text-align:center;font-size:19px;line-height:1.45;overflow-x:auto;"><div style="margin:7px 0;">Debt-to-Equity = <span style="display:inline-block;text-align:center;vertical-align:middle;line-height:1.15;margin:0 6px;"><span style="display:block;border-bottom:1px solid #F8F8F8;padding:0 10px;">Total Liabilities</span><span style="display:block;padding:2px 10px 0 10px;">Shareholders' Equity</span></span></div><div style="margin:7px 0;">= <span style="display:inline-block;text-align:center;vertical-align:middle;line-height:1.15;margin:0 6px;"><span style="display:block;border-bottom:1px solid #F8F8F8;padding:0 10px;">12,819.8</span><span style="display:block;padding:2px 10px 0 10px;">8,579.2</span></span></div><div style="margin:7px 0;">= 1.49</div></div><p style="font-size:16px;line-height:1.6;margin:14px 0 0 0;"><strong style="color:#CFB87C;">Readout:</strong> Trane has 1.49 dollars of liabilities for each 1.00 dollar of shareholders' equity.</p>
# <hr style="border:none;border-top:8px solid #CFB87C;margin:18px 0 0 0;">
# </div>

# %% [markdown]
# <div style="background-color:#000000;color:#F8F8F8;padding:25px;border-radius:10px;border-left:8px solid #CFB87C;border-right:8px solid #A2A4A3;font-family:Helvetica Neue,Arial,sans-serif;">
# <h2 style="color:#CFB87C;margin:0 0 14px 0;">Interest Coverage</h2>
# <div style="font-size:34px;font-weight:bold;color:#F8F8F8;margin:0 0 16px 0;">19.16</div><div style="background-color:#111111;color:#F8F8F8;padding:18px;border-radius:8px;border:1px solid #565A5C;text-align:center;font-size:19px;line-height:1.45;overflow-x:auto;"><div style="margin:7px 0;">Interest Coverage = <span style="display:inline-block;text-align:center;vertical-align:middle;line-height:1.15;margin:0 6px;"><span style="display:block;border-bottom:1px solid #F8F8F8;padding:0 10px;">EBITDA</span><span style="display:block;padding:2px 10px 0 10px;">Interest Expense</span></span></div><div style="margin:7px 0;">= <span style="display:inline-block;text-align:center;vertical-align:middle;line-height:1.15;margin:0 6px;"><span style="display:block;border-bottom:1px solid #F8F8F8;padding:0 10px;">4,343.7</span><span style="display:block;padding:2px 10px 0 10px;">226.7</span></span></div><div style="margin:7px 0;">= 19.16</div></div><p style="font-size:16px;line-height:1.6;margin:14px 0 0 0;"><strong style="color:#CFB87C;">Readout:</strong> EBITDA covers interest expense about 19.16 times.</p><p style="font-size:14px;color:#A2A4A3;line-height:1.5;margin:10px 0 0 0;"><strong style="color:#CFB87C;">Note:</strong> EBITDA here equals operating income plus depreciation and amortization.</p>
# <hr style="border:none;border-top:8px solid #CFB87C;margin:18px 0 0 0;">
# </div>

# %% [markdown]
# <div style="background-color:#000000;color:#F8F8F8;padding:25px;border-radius:10px;border-left:8px solid #CFB87C;border-right:8px solid #A2A4A3;font-family:Helvetica Neue,Arial,sans-serif;">
# <h2 style="color:#CFB87C;margin:0 0 14px 0;">Times Interest Earned</h2>
# <div style="font-size:34px;font-weight:bold;color:#F8F8F8;margin:0 0 16px 0;">17.50</div><div style="background-color:#111111;color:#F8F8F8;padding:18px;border-radius:8px;border:1px solid #565A5C;text-align:center;font-size:19px;line-height:1.45;overflow-x:auto;"><div style="margin:7px 0;">Times Interest Earned = <span style="display:inline-block;text-align:center;vertical-align:middle;line-height:1.15;margin:0 6px;"><span style="display:block;border-bottom:1px solid #F8F8F8;padding:0 10px;">Operating Income</span><span style="display:block;padding:2px 10px 0 10px;">Interest Expense</span></span></div><div style="margin:7px 0;">= <span style="display:inline-block;text-align:center;vertical-align:middle;line-height:1.15;margin:0 6px;"><span style="display:block;border-bottom:1px solid #F8F8F8;padding:0 10px;">3,967.4</span><span style="display:block;padding:2px 10px 0 10px;">226.7</span></span></div><div style="margin:7px 0;">= 17.50</div></div><p style="font-size:16px;line-height:1.6;margin:14px 0 0 0;"><strong style="color:#CFB87C;">Readout:</strong> Operating income covers interest expense about 17.50 times.</p>
# <hr style="border:none;border-top:8px solid #CFB87C;margin:18px 0 0 0;">
# </div>

# %% [markdown]
# <div style="background-color:#000000;color:#F8F8F8;padding:25px;border-radius:10px;border-left:8px solid #CFB87C;border-right:8px solid #A2A4A3;font-family:Helvetica Neue,Arial,sans-serif;">
# <h2 style="color:#CFB87C;margin:0 0 14px 0;">Return on Assets</h2>
# <div style="font-size:34px;font-weight:bold;color:#F8F8F8;margin:0 0 16px 0;">13.6%</div><div style="background-color:#111111;color:#F8F8F8;padding:18px;border-radius:8px;border:1px solid #565A5C;text-align:center;font-size:19px;line-height:1.45;overflow-x:auto;"><div style="margin:7px 0;">ROA = <span style="display:inline-block;text-align:center;vertical-align:middle;line-height:1.15;margin:0 6px;"><span style="display:block;border-bottom:1px solid #F8F8F8;padding:0 10px;">Net Earnings Attributable to Trane</span><span style="display:block;padding:2px 10px 0 10px;">Total Assets</span></span></div><div style="margin:7px 0;">= <span style="display:inline-block;text-align:center;vertical-align:middle;line-height:1.15;margin:0 6px;"><span style="display:block;border-bottom:1px solid #F8F8F8;padding:0 10px;">2,918.6</span><span style="display:block;padding:2px 10px 0 10px;">21,420.7</span></span></div><div style="margin:7px 0;">= 13.6%</div></div><p style="font-size:16px;line-height:1.6;margin:14px 0 0 0;"><strong style="color:#CFB87C;">Readout:</strong> Trane generated earnings equal to 13.6% of year-end assets.</p><p style="font-size:14px;color:#A2A4A3;line-height:1.5;margin:10px 0 0 0;"><strong style="color:#CFB87C;">Note:</strong> This uses year-end total assets to match the simple course formula.</p>
# <hr style="border:none;border-top:8px solid #CFB87C;margin:18px 0 0 0;">
# </div>

# %% [markdown]
# <div style="background-color:#000000;color:#F8F8F8;padding:25px;border-radius:10px;border-left:8px solid #CFB87C;border-right:8px solid #A2A4A3;font-family:Helvetica Neue,Arial,sans-serif;">
# <h2 style="color:#CFB87C;margin:0 0 14px 0;">Return on Equity</h2>
# <div style="font-size:34px;font-weight:bold;color:#F8F8F8;margin:0 0 16px 0;">34.0%</div><div style="background-color:#111111;color:#F8F8F8;padding:18px;border-radius:8px;border:1px solid #565A5C;text-align:center;font-size:19px;line-height:1.45;overflow-x:auto;"><div style="margin:7px 0;">ROE = <span style="display:inline-block;text-align:center;vertical-align:middle;line-height:1.15;margin:0 6px;"><span style="display:block;border-bottom:1px solid #F8F8F8;padding:0 10px;">Net Earnings Attributable to Trane</span><span style="display:block;padding:2px 10px 0 10px;">Shareholders' Equity</span></span></div><div style="margin:7px 0;">= <span style="display:inline-block;text-align:center;vertical-align:middle;line-height:1.15;margin:0 6px;"><span style="display:block;border-bottom:1px solid #F8F8F8;padding:0 10px;">2,918.6</span><span style="display:block;padding:2px 10px 0 10px;">8,579.2</span></span></div><div style="margin:7px 0;">= 34.0%</div></div><p style="font-size:16px;line-height:1.6;margin:14px 0 0 0;"><strong style="color:#CFB87C;">Readout:</strong> Trane generated earnings equal to 34.0% of year-end shareholders' equity.</p><p style="font-size:14px;color:#A2A4A3;line-height:1.5;margin:10px 0 0 0;"><strong style="color:#CFB87C;">Note:</strong> This uses year-end shareholders' equity to match the simple course formula.</p>
# <hr style="border:none;border-top:8px solid #CFB87C;margin:18px 0 0 0;">
# </div>

# %% [markdown]
# <div style="background-color:#000000;color:#F8F8F8;padding:25px;border-radius:10px;border-left:8px solid #CFB87C;border-right:8px solid #A2A4A3;font-family:Helvetica Neue,Arial,sans-serif;">
# <h2 style="color:#CFB87C;margin:0 0 14px 0;">Basic EPS</h2>
# <div style="font-size:34px;font-weight:bold;color:#F8F8F8;margin:0 0 16px 0;">&#36;13.09</div><div style="background-color:#111111;color:#F8F8F8;padding:18px;border-radius:8px;border:1px solid #565A5C;text-align:center;font-size:19px;line-height:1.45;overflow-x:auto;"><div style="margin:7px 0;">Basic EPS = 13.09</div></div><p style="font-size:16px;line-height:1.6;margin:14px 0 0 0;"><strong style="color:#CFB87C;">Readout:</strong> Basic earnings per share were 13.09 dollars in 2025.</p><p style="font-size:14px;color:#A2A4A3;line-height:1.5;margin:10px 0 0 0;"><strong style="color:#CFB87C;">Note:</strong> EPS is disclosed directly in the income statement.</p>
# <hr style="border:none;border-top:8px solid #CFB87C;margin:18px 0 0 0;">
# </div>

# %% [markdown]
# <div style="background-color:#000000;color:#F8F8F8;padding:25px;border-radius:10px;border-left:8px solid #CFB87C;border-right:8px solid #A2A4A3;font-family:Helvetica Neue,Arial,sans-serif;">
# <h2 style="color:#CFB87C;margin:0 0 14px 0;">Diluted EPS</h2>
# <div style="font-size:34px;font-weight:bold;color:#F8F8F8;margin:0 0 16px 0;">&#36;12.98</div><div style="background-color:#111111;color:#F8F8F8;padding:18px;border-radius:8px;border:1px solid #565A5C;text-align:center;font-size:19px;line-height:1.45;overflow-x:auto;"><div style="margin:7px 0;">Diluted EPS = 12.98</div></div><p style="font-size:16px;line-height:1.6;margin:14px 0 0 0;"><strong style="color:#CFB87C;">Readout:</strong> Diluted earnings per share were 12.98 dollars in 2025.</p><p style="font-size:14px;color:#A2A4A3;line-height:1.5;margin:10px 0 0 0;"><strong style="color:#CFB87C;">Note:</strong> EPS is disclosed directly in the income statement.</p>
# <hr style="border:none;border-top:8px solid #CFB87C;margin:18px 0 0 0;">
# </div>

# %% [markdown]
# <div style="background-color:#000000;color:#F8F8F8;padding:25px;border-radius:10px;border-left:8px solid #CFB87C;border-right:8px solid #A2A4A3;font-family:Helvetica Neue,Arial,sans-serif;">
# <h2 style="color:#A2A4A3;margin:0 0 12px 0;">Part 4: Required Financial Statement Screenshots</h2>
# <p style="font-size:16px;line-height:1.6;margin:0;">These are the required financial statement screenshots from the 2025 annual report.</p>
# <hr style="border:none;border-top:8px solid #CFB87C;margin:18px 0 0 0;">
# </div>

# %% [markdown]
# <div style="background-color:#000000;color:#F8F8F8;padding:25px;border-radius:10px;border-left:8px solid #A2A4A3;border-right:8px solid #A2A4A3;font-family:Helvetica Neue,Arial,sans-serif;">
# <h2 style="color:#CFB87C;margin:0 0 14px 0;">Consolidated Statements of Earnings</h2>
# <div style="background-color:#F8F8F8;padding:10px;border-radius:8px;text-align:center;"><img src="images/income_statement.png" alt="Consolidated Statements of Earnings" style="width:100%;max-width:850px;height:auto;"></div><p style="font-size:14px;color:#A2A4A3;line-height:1.5;margin:12px 0 0 0;">Source: Trane Technologies 2025 Annual Report, page F-4, PDF page 161.</p>
# <hr style="border:none;border-top:8px solid #CFB87C;margin:18px 0 0 0;">
# </div>

# %% [markdown]
# <div style="background-color:#000000;color:#F8F8F8;padding:25px;border-radius:10px;border-left:8px solid #A2A4A3;border-right:8px solid #A2A4A3;font-family:Helvetica Neue,Arial,sans-serif;">
# <h2 style="color:#CFB87C;margin:0 0 14px 0;">Consolidated Balance Sheets</h2>
# <div style="background-color:#F8F8F8;padding:10px;border-radius:8px;text-align:center;"><img src="images/balance_sheet.png" alt="Consolidated Balance Sheets" style="width:100%;max-width:850px;height:auto;"></div><p style="font-size:14px;color:#A2A4A3;line-height:1.5;margin:12px 0 0 0;">Source: Trane Technologies 2025 Annual Report, page F-6, PDF page 163.</p>
# <hr style="border:none;border-top:8px solid #CFB87C;margin:18px 0 0 0;">
# </div>

# %% [markdown]
# <div style="background-color:#000000;color:#F8F8F8;padding:25px;border-radius:10px;border-left:8px solid #A2A4A3;border-right:8px solid #A2A4A3;font-family:Helvetica Neue,Arial,sans-serif;">
# <h2 style="color:#CFB87C;margin:0 0 14px 0;">Consolidated Statements of Cash Flows</h2>
# <div style="background-color:#F8F8F8;padding:10px;border-radius:8px;text-align:center;"><img src="images/cash_flow_statement.png" alt="Consolidated Statements of Cash Flows" style="width:100%;max-width:850px;height:auto;"></div><p style="font-size:14px;color:#A2A4A3;line-height:1.5;margin:12px 0 0 0;">Source: Trane Technologies 2025 Annual Report, page F-8, PDF page 165.</p>
# <hr style="border:none;border-top:8px solid #CFB87C;margin:18px 0 0 0;">
# </div>

# %% [markdown]
# <div style="background-color:#000000;color:#F8F8F8;padding:25px;border-radius:10px;border-left:8px solid #CFB87C;border-right:8px solid #A2A4A3;font-family:Helvetica Neue,Arial,sans-serif;">
# <h2 style="color:#A2A4A3;margin:0 0 12px 0;">Beyond the Assignment: Annual Trend Review</h2>
# <p style="font-size:16px;line-height:1.6;margin:0;">After the required assignment work, I added a short annual trend check using 2023, 2024, and 2025. I am not mixing Q1 2026 into the annual comparison.</p>
# <hr style="border:none;border-top:8px solid #CFB87C;margin:18px 0 0 0;">
# </div>

# %% [markdown]
# <div style="background-color:#000000;color:#F8F8F8;padding:25px;border-radius:10px;border-left:8px solid #CFB87C;border-right:8px solid #A2A4A3;font-family:Helvetica Neue,Arial,sans-serif;">
# <h2 style="color:#CFB87C;margin:0 0 14px 0;">Net Revenues</h2>
# <div style="display:inline-block;width:235px;margin:6px;"><div style="display:inline-block;vertical-align:top;width:205px;min-height:78px;background-color:#111111;border:1px solid #565A5C;border-left:6px solid #CFB87C;border-radius:8px;padding:12px;margin:6px;"><div style="color:#A2A4A3;font-size:12px;text-transform:uppercase;letter-spacing:.06em;">2023</div><div style="color:#F8F8F8;font-size:23px;font-weight:bold;margin-top:7px;">&#36;17,677.6M</div></div></div><div style="display:inline-block;width:235px;margin:6px;"><div style="display:inline-block;vertical-align:top;width:205px;min-height:78px;background-color:#111111;border:1px solid #565A5C;border-left:6px solid #CFB87C;border-radius:8px;padding:12px;margin:6px;"><div style="color:#A2A4A3;font-size:12px;text-transform:uppercase;letter-spacing:.06em;">2024</div><div style="color:#F8F8F8;font-size:23px;font-weight:bold;margin-top:7px;">&#36;19,838.2M</div></div></div><div style="display:inline-block;width:235px;margin:6px;"><div style="display:inline-block;vertical-align:top;width:205px;min-height:78px;background-color:#111111;border:1px solid #565A5C;border-left:6px solid #CFB87C;border-radius:8px;padding:12px;margin:6px;"><div style="color:#A2A4A3;font-size:12px;text-transform:uppercase;letter-spacing:.06em;">2025</div><div style="color:#F8F8F8;font-size:23px;font-weight:bold;margin-top:7px;">&#36;21,321.9M</div></div></div><div style="display:inline-block;width:235px;margin:6px;"><div style="display:inline-block;vertical-align:top;width:205px;min-height:78px;background-color:#111111;border:1px solid #565A5C;border-left:6px solid #CFB87C;border-radius:8px;padding:12px;margin:6px;"><div style="color:#A2A4A3;font-size:12px;text-transform:uppercase;letter-spacing:.06em;">2025 YoY</div><div style="color:#F8F8F8;font-size:23px;font-weight:bold;margin-top:7px;">7.5%</div></div></div>
# <hr style="border:none;border-top:8px solid #CFB87C;margin:18px 0 0 0;">
# </div>

# %% [markdown]
# <div style="background-color:#000000;color:#F8F8F8;padding:25px;border-radius:10px;border-left:8px solid #CFB87C;border-right:8px solid #A2A4A3;font-family:Helvetica Neue,Arial,sans-serif;">
# <h2 style="color:#CFB87C;margin:0 0 14px 0;">Operating Income</h2>
# <div style="display:inline-block;width:235px;margin:6px;"><div style="display:inline-block;vertical-align:top;width:205px;min-height:78px;background-color:#111111;border:1px solid #565A5C;border-left:6px solid #CFB87C;border-radius:8px;padding:12px;margin:6px;"><div style="color:#A2A4A3;font-size:12px;text-transform:uppercase;letter-spacing:.06em;">2023</div><div style="color:#F8F8F8;font-size:23px;font-weight:bold;margin-top:7px;">&#36;2,894.0M</div></div></div><div style="display:inline-block;width:235px;margin:6px;"><div style="display:inline-block;vertical-align:top;width:205px;min-height:78px;background-color:#111111;border:1px solid #565A5C;border-left:6px solid #CFB87C;border-radius:8px;padding:12px;margin:6px;"><div style="color:#A2A4A3;font-size:12px;text-transform:uppercase;letter-spacing:.06em;">2024</div><div style="color:#F8F8F8;font-size:23px;font-weight:bold;margin-top:7px;">&#36;3,500.1M</div></div></div><div style="display:inline-block;width:235px;margin:6px;"><div style="display:inline-block;vertical-align:top;width:205px;min-height:78px;background-color:#111111;border:1px solid #565A5C;border-left:6px solid #CFB87C;border-radius:8px;padding:12px;margin:6px;"><div style="color:#A2A4A3;font-size:12px;text-transform:uppercase;letter-spacing:.06em;">2025</div><div style="color:#F8F8F8;font-size:23px;font-weight:bold;margin-top:7px;">&#36;3,967.4M</div></div></div><div style="display:inline-block;width:235px;margin:6px;"><div style="display:inline-block;vertical-align:top;width:205px;min-height:78px;background-color:#111111;border:1px solid #565A5C;border-left:6px solid #CFB87C;border-radius:8px;padding:12px;margin:6px;"><div style="color:#A2A4A3;font-size:12px;text-transform:uppercase;letter-spacing:.06em;">2025 YoY</div><div style="color:#F8F8F8;font-size:23px;font-weight:bold;margin-top:7px;">13.4%</div></div></div>
# <hr style="border:none;border-top:8px solid #CFB87C;margin:18px 0 0 0;">
# </div>

# %% [markdown]
# <div style="background-color:#000000;color:#F8F8F8;padding:25px;border-radius:10px;border-left:8px solid #CFB87C;border-right:8px solid #A2A4A3;font-family:Helvetica Neue,Arial,sans-serif;">
# <h2 style="color:#CFB87C;margin:0 0 14px 0;">Net Earnings Attributable</h2>
# <div style="display:inline-block;width:235px;margin:6px;"><div style="display:inline-block;vertical-align:top;width:205px;min-height:78px;background-color:#111111;border:1px solid #565A5C;border-left:6px solid #CFB87C;border-radius:8px;padding:12px;margin:6px;"><div style="color:#A2A4A3;font-size:12px;text-transform:uppercase;letter-spacing:.06em;">2023</div><div style="color:#F8F8F8;font-size:23px;font-weight:bold;margin-top:7px;">&#36;2,023.9M</div></div></div><div style="display:inline-block;width:235px;margin:6px;"><div style="display:inline-block;vertical-align:top;width:205px;min-height:78px;background-color:#111111;border:1px solid #565A5C;border-left:6px solid #CFB87C;border-radius:8px;padding:12px;margin:6px;"><div style="color:#A2A4A3;font-size:12px;text-transform:uppercase;letter-spacing:.06em;">2024</div><div style="color:#F8F8F8;font-size:23px;font-weight:bold;margin-top:7px;">&#36;2,567.9M</div></div></div><div style="display:inline-block;width:235px;margin:6px;"><div style="display:inline-block;vertical-align:top;width:205px;min-height:78px;background-color:#111111;border:1px solid #565A5C;border-left:6px solid #CFB87C;border-radius:8px;padding:12px;margin:6px;"><div style="color:#A2A4A3;font-size:12px;text-transform:uppercase;letter-spacing:.06em;">2025</div><div style="color:#F8F8F8;font-size:23px;font-weight:bold;margin-top:7px;">&#36;2,918.6M</div></div></div><div style="display:inline-block;width:235px;margin:6px;"><div style="display:inline-block;vertical-align:top;width:205px;min-height:78px;background-color:#111111;border:1px solid #565A5C;border-left:6px solid #CFB87C;border-radius:8px;padding:12px;margin:6px;"><div style="color:#A2A4A3;font-size:12px;text-transform:uppercase;letter-spacing:.06em;">2025 YoY</div><div style="color:#F8F8F8;font-size:23px;font-weight:bold;margin-top:7px;">13.7%</div></div></div>
# <hr style="border:none;border-top:8px solid #CFB87C;margin:18px 0 0 0;">
# </div>

# %% [markdown]
# <div style="background-color:#000000;color:#F8F8F8;padding:25px;border-radius:10px;border-left:8px solid #CFB87C;border-right:8px solid #A2A4A3;font-family:Helvetica Neue,Arial,sans-serif;">
# <h2 style="color:#CFB87C;margin:0 0 14px 0;">Operating Cash Flow</h2>
# <div style="display:inline-block;width:235px;margin:6px;"><div style="display:inline-block;vertical-align:top;width:205px;min-height:78px;background-color:#111111;border:1px solid #565A5C;border-left:6px solid #CFB87C;border-radius:8px;padding:12px;margin:6px;"><div style="color:#A2A4A3;font-size:12px;text-transform:uppercase;letter-spacing:.06em;">2023</div><div style="color:#F8F8F8;font-size:23px;font-weight:bold;margin-top:7px;">&#36;2,389.6M</div></div></div><div style="display:inline-block;width:235px;margin:6px;"><div style="display:inline-block;vertical-align:top;width:205px;min-height:78px;background-color:#111111;border:1px solid #565A5C;border-left:6px solid #CFB87C;border-radius:8px;padding:12px;margin:6px;"><div style="color:#A2A4A3;font-size:12px;text-transform:uppercase;letter-spacing:.06em;">2024</div><div style="color:#F8F8F8;font-size:23px;font-weight:bold;margin-top:7px;">&#36;3,145.6M</div></div></div><div style="display:inline-block;width:235px;margin:6px;"><div style="display:inline-block;vertical-align:top;width:205px;min-height:78px;background-color:#111111;border:1px solid #565A5C;border-left:6px solid #CFB87C;border-radius:8px;padding:12px;margin:6px;"><div style="color:#A2A4A3;font-size:12px;text-transform:uppercase;letter-spacing:.06em;">2025</div><div style="color:#F8F8F8;font-size:23px;font-weight:bold;margin-top:7px;">&#36;3,194.5M</div></div></div><div style="display:inline-block;width:235px;margin:6px;"><div style="display:inline-block;vertical-align:top;width:205px;min-height:78px;background-color:#111111;border:1px solid #565A5C;border-left:6px solid #CFB87C;border-radius:8px;padding:12px;margin:6px;"><div style="color:#A2A4A3;font-size:12px;text-transform:uppercase;letter-spacing:.06em;">2025 YoY</div><div style="color:#F8F8F8;font-size:23px;font-weight:bold;margin-top:7px;">1.6%</div></div></div>
# <hr style="border:none;border-top:8px solid #CFB87C;margin:18px 0 0 0;">
# </div>

# %% [markdown]
# <div style="background-color:#000000;color:#F8F8F8;padding:25px;border-radius:10px;border-left:8px solid #CFB87C;border-right:8px solid #A2A4A3;font-family:Helvetica Neue,Arial,sans-serif;">
# <h2 style="color:#CFB87C;margin:0 0 14px 0;">Diluted EPS</h2>
# <div style="display:inline-block;width:235px;margin:6px;"><div style="display:inline-block;vertical-align:top;width:205px;min-height:78px;background-color:#111111;border:1px solid #565A5C;border-left:6px solid #CFB87C;border-radius:8px;padding:12px;margin:6px;"><div style="color:#A2A4A3;font-size:12px;text-transform:uppercase;letter-spacing:.06em;">2023</div><div style="color:#F8F8F8;font-size:23px;font-weight:bold;margin-top:7px;">&#36;8.8</div></div></div><div style="display:inline-block;width:235px;margin:6px;"><div style="display:inline-block;vertical-align:top;width:205px;min-height:78px;background-color:#111111;border:1px solid #565A5C;border-left:6px solid #CFB87C;border-radius:8px;padding:12px;margin:6px;"><div style="color:#A2A4A3;font-size:12px;text-transform:uppercase;letter-spacing:.06em;">2024</div><div style="color:#F8F8F8;font-size:23px;font-weight:bold;margin-top:7px;">&#36;11.2</div></div></div><div style="display:inline-block;width:235px;margin:6px;"><div style="display:inline-block;vertical-align:top;width:205px;min-height:78px;background-color:#111111;border:1px solid #565A5C;border-left:6px solid #CFB87C;border-radius:8px;padding:12px;margin:6px;"><div style="color:#A2A4A3;font-size:12px;text-transform:uppercase;letter-spacing:.06em;">2025</div><div style="color:#F8F8F8;font-size:23px;font-weight:bold;margin-top:7px;">&#36;13.0</div></div></div><div style="display:inline-block;width:235px;margin:6px;"><div style="display:inline-block;vertical-align:top;width:205px;min-height:78px;background-color:#111111;border:1px solid #565A5C;border-left:6px solid #CFB87C;border-radius:8px;padding:12px;margin:6px;"><div style="color:#A2A4A3;font-size:12px;text-transform:uppercase;letter-spacing:.06em;">2025 YoY</div><div style="color:#F8F8F8;font-size:23px;font-weight:bold;margin-top:7px;">15.5%</div></div></div>
# <hr style="border:none;border-top:8px solid #CFB87C;margin:18px 0 0 0;">
# </div>

# %% [markdown]
# <div style="background-color:#000000;color:#F8F8F8;padding:25px;border-radius:10px;border-left:8px solid #CFB87C;border-right:8px solid #A2A4A3;font-family:Helvetica Neue,Arial,sans-serif;">
# <h2 style="color:#CFB87C;margin:0 0 14px 0;">Final conclusion</h2>
# <p style="font-size:16px;line-height:1.6;margin:0 0 12px 0;">Trane Technologies looks financially stable and profitable based on the statements reviewed. I selected this company because Thermo King is part of Trane Technologies. Thermo King is my primary vendor, so we track Trane Technologies closely because the health of our primary vendor is important to my financial well being and employment.</p><p style="font-size:16px;line-height:1.6;margin:0 0 12px 0;">The main watch items are leverage, cash flow growth, and whether service revenue continues to expand. I do not see an obvious red flag in the 2025 statements reviewed for this assignment.</p>
# <hr style="border:none;border-top:8px solid #CFB87C;margin:18px 0 0 0;">
# </div>

# %% [markdown]
# <div style="background-color:#000000;color:#F8F8F8;padding:25px;border-radius:10px;border-left:8px solid #CFB87C;border-right:8px solid #A2A4A3;font-family:Helvetica Neue,Arial,sans-serif;">
# <h2 style="color:#CFB87C;margin:0 0 14px 0;">Sources</h2>
# <ul style="font-size:16px;line-height:1.55;margin:0 0 8px 22px;padding:0;"><li style="margin:5px 0;">Trane Technologies 2025 Annual Report / Form 10-K, saved locally in the 2025 folder.</li><li style="margin:5px 0;">Trane Technologies Q4 2025 Earnings Presentation, slide 5.</li><li style="margin:5px 0;"><a href="https://investors.tranetechnologies.com/financial-information/financial-summary/default.aspx" style="color:#CFB87C;">Trane Technologies Investor Financial Summary</a></li><li style="margin:5px 0;">Extracted values and supporting files are saved in the local data and images folders for auditability.</li></ul>
# <hr style="border:none;border-top:8px solid #CFB87C;margin:18px 0 0 0;">
# </div>
